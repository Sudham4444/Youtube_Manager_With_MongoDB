# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 34.2 MB/s eta 0:00:00
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 17.7 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.6.1 pymongo-4.8.0

# %%
import pymongo

# %%
from pymongo import MongoClient
from bson import ObjectId
import os

# Fetch credentials from environment variables
username = os.getenv('MONGO_USERNAME')
password = os.getenv('MONGO_PASSWORD')

client = MongoClient(f"mongodb+srv://{username}:{password}@cluster0.wntvop7.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0", tlsAllowInvalidCertificates=True)

print(client)
db = client["ytmanager"]
video_collection = db["videos"]

print(video_collection)

def add_video(name, time):
    video_collection.insert_one({"name": name, "time": time})

def list_videos():
    for video in video_collection.find():
        print(f"ID: {video['_id']}, Name: {video['name']} and Time: {video['time']}")

def update_video(video_id, new_name, new_time):
    video_collection.update_one({'_id': ObjectId(video_id)}, {"$set": {"name": new_name, "time": new_time}})

def delete_video(video_id):
    video_collection.delete_one({"_id": ObjectId(video_id)})
    # Fixed the issue by converting video_id to ObjectId

def main():
    while True:
        print("\nYouTube Manager App")
        print("1. List all videos")
        print("2. Add a new video")
        print("3. Update a video")
        print("4. Delete a video")
        print("5. Exit the app")
        choice = input("Enter your choice: ")

        if choice == '1':
            list_videos()
        elif choice == '2':
            name = input("Enter the video name: ")
            time = input("Enter the video time: ")
            add_video(name, time)
        elif choice == '3':
            video_id = input("Enter the video id to update: ")
            name = input("Enter the updated video name: ")
            time = input("Enter the updated video time: ")
            update_video(video_id, name, time)
        elif choice == '4':
            video_id = input("Enter the video id to delete: ")
            delete_video(video_id)
        elif choice == '5':
            break
        else:
            print("Invalid choice")

if __name__ == "__main__":
    main()
# Out:
# MongoClient(host=['ac-mzfusb6-shard-00-01.wntvop7.mongodb.net:27017', 'ac-mzfusb6-shard-00-02.wntvop7.mongodb.net:27017', 'ac-mzfusb6-shard-00-00.wntvop7.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-1bi4ad-shard-0', tls=True, tlsallowinvalidcertificates=True, tlsdisableocspendpointcheck=True)
# Collection(Database(MongoClient(host=['ac-mzfusb6-shard-00-01.wntvop7.mongodb.net:27017', 'ac-mzfusb6-shard-00-02.wntvop7.mongodb.net:27017', 'ac-mzfusb6-shard-00-00.wntvop7.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-1bi4ad-shard-0', tls=True, tlsallowinvalidcertificates=True, tlsdisableocspendpointcheck=True), 'ytmanager'), 'videos')
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter the video name: let's grow
# Enter the video time: 60 min
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter the video name: let's code
# Enter the video time: 1 hr
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter the video name: DSA
# Enter the video time: 12 hrs
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter the video name: data analyst
# Enter the video time: 12 hrs
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter the video name: python
# Enter the video time: 10 hrs
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 2
# Enter the video name: django
# Enter the video time: 10 hrs
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 1
# ID: 66ab5a7859a8edbe2a1a48ec, Name: let's grow and Time: 60 min
# ID: 66ab5a8759a8edbe2a1a48ed, Name: let's code and Time: 1 hr
# ID: 66ab5a9459a8edbe2a1a48ee, Name: DSA and Time: 12 hrs
# ID: 66ab5aa959a8edbe2a1a48ef, Name: data analyst and Time: 12 hrs
# ID: 66ab5abc59a8edbe2a1a48f0, Name: python  and Time: 10 hrs
# ID: 66ab5acd59a8edbe2a1a48f1, Name: django and Time: 10 hrs
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 3
# Enter the video id to update: 66ab5a8759a8edbe2a1a48ed
# Enter the updated video name: let's code
# Enter the updated video time: 10 hrs
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 1
# ID: 66ab5a7859a8edbe2a1a48ec, Name: let's grow and Time: 60 min
# ID: 66ab5a8759a8edbe2a1a48ed, Name: let's code and Time: 10 hrs
# ID: 66ab5a9459a8edbe2a1a48ee, Name: DSA and Time: 12 hrs
# ID: 66ab5aa959a8edbe2a1a48ef, Name: data analyst and Time: 12 hrs
# ID: 66ab5abc59a8edbe2a1a48f0, Name: python  and Time: 10 hrs
# ID: 66ab5acd59a8edbe2a1a48f1, Name: django and Time: 10 hrs
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 4
# Enter the video id to delete: 66ab5a7859a8edbe2a1a48ec
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 1
# ID: 66ab5a8759a8edbe2a1a48ed, Name: let's code and Time: 10 hrs
# ID: 66ab5a9459a8edbe2a1a48ee, Name: DSA and Time: 12 hrs
# ID: 66ab5aa959a8edbe2a1a48ef, Name: data analyst and Time: 12 hrs
# ID: 66ab5abc59a8edbe2a1a48f0, Name: python  and Time: 10 hrs
# ID: 66ab5acd59a8edbe2a1a48f1, Name: django and Time: 10 hrs
#
# YouTube Manager App
# 1. List all videos
# 2. Add a new video
# 3. Update a video
# 4. Delete a video
# 5. Exit the app
# Enter your choice: 5
